# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
os.chdir(parent_dir)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/alvarovilladangos/Desktop/TradingBot/Forex

# %%
import time

from ibkr.app import IBApp
from ibkr.contract import forex

app = IBApp("127.0.0.1", 7497, client_id=7765465, account="DUE310707")
eur = forex("GBP/USD")
for tick in app.get_streaming_data(99, eur):
    print(tick)
time.sleep(30)
app.disconnect()
# Out:
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:hfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfarm.nj
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:jfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfuture
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:cashfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:eufarmnj
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfarm
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:euhmds
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:fundfarm
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:ushmds
# ERROR -1 2158 La conexión de la granja de datos "sec-def" funciona correctamente:secdefnj
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:cashhmds
# {99: (1734994576, 1.2537, 1.25391, Decimal('2000000'), Decimal('2000000'))}
# Tick(time=1734994576, bid_price=1.2537, ask_price=1.25391, bid_size=2000000, ask_size=2000000, timestamp_=Timestamp('2024-12-23 22:56:16'))
# {99: (1734994650, 1.25368, 1.25389, Decimal('2000000'), Decimal('2000000'))}
# Tick(time=1734994650, bid_price=1.25368, ask_price=1.25389, bid_size=2000000, ask_size=2000000, timestamp_=Timestamp('2024-12-23 22:57:30'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 app = IBApp("127.0.0.1", 7497, client_id=7765465, account="DUE310707")
#       7 eur = forex("GBP/USD")
# ----> 8 for tick in app.get_streaming_data(99, eur):
#       9     print(tick)
#      10 time.sleep(30)
#
# File ~/Desktop/TradingBot/Forex/ibkr/client.py:325, in IBClient.get_streaming_data(self, request_id, contract)
#     322 time.sleep(10)  # Allow some initial data to arrive
#     324 while True:
# --> 325     if self.stream_event.is_set():  # Wait for new data
#     326         print(self.streaming_data)
#     327         yield Tick(*self.streaming_data[request_id])  # Yield the tick data
#
# KeyboardInterrupt:
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usopt
# ERROR -1 2108 La conexión al centro de datos está inactiva pero debería estar disponible bajo demanda.usopt
# ERROR -1 2108 La conexión al centro de datos está inactiva pero debería estar disponible bajo demanda.usopt
