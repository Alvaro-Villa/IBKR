# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
os.chdir(parent_dir)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/alvarovilladangos/Desktop/TradingBot/Forex

# %%
from ibkr.app import IBApp
import time
app = IBApp("127.0.0.1", 4002, client_id=7321, account="DUE310707")

time.sleep(30)

print(app.cumulative_returns)
print(app.max_drawdown)
print(app.volatility)
print(app.omega_ratio)
print(app.sharpe_ratio)
print(app.cvar)

# request_id, warm_up=5, interval=60, pnl_type="unrealized_pnl"
# for snapshot in app.stream_portfolio_returns(request_id=99, window=5, interval=5, pnl_type="unrealized_pnl"):
#     print(snapshot)

app.disconnect()
# Out:
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:cashfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfarm
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:cashhmds
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:ushmds
# ERROR -1 2158 La conexión de la granja de datos "sec-def" funciona correctamente:secdefnj
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:15.702363'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:20.718744'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:25.732139'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:30.743890'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:35.756786'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:40.766242'), 'pnl': 0.0}
# 2024-12-17 21:05:20.718744    1.0
# 2024-12-17 21:05:25.732139    1.0
# 2024-12-17 21:05:30.743890    1.0
# 2024-12-17 21:05:35.756786    1.0
# 2024-12-17 21:05:40.766242    1.0
# dtype: float64
# 0.0
# 0.0
# nan
# nan
# /Users/alvarovilladangos/Desktop/TradingBot/Forex/ibkr/app.py:216: RuntimeWarning: invalid value encountered in scalar divide
#   return self.portfolio_returns.mean() / self.portfolio_returns.std(ddof=1)
# (np.float64(0.0), np.float64(0.0))
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:45.770069'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:50.776395'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:05:55.789988'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:00.800231'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:05.815679'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:10.826168'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:15.839845'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:20.850841'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:25.862179'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:30.877632'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:35.890567'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:40.909253'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:45.920817'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:50.934759'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:06:55.944188'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:00.958122'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:05.971326'), 'pnl': 0.0}
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:10.985167'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:16.000753'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:21.015269'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:26.022904'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:31.036926'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:36.049619'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:46.068718'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:51.082685'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:07:56.094425'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:01.106683'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:06.118815'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:11.134295'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:16.147555'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:21.161776'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:26.173030'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:31.185826'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:36.199638'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:41.207433'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:46.217060'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:51.228865'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:08:56.250336'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:01.261683'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:06.275771'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:11.289036'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:21.310443'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:26.316515'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:31.325499'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:36.338118'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:41.348901'), 'pnl': 0.0}
# ERROR -1 504 Not connected
# ERROR -1 504 Not connected
# Sanpshot: {'date': Timestamp('2024-12-17 21:09:46.361378'), 'pnl': 0.0}
