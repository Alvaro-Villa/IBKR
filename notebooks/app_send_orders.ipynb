# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
os.chdir(parent_dir)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/alvarovilladangos/Desktop/TradingBot/Forex

# %%
import time
from ibkr.order import market, limit, stop, BUY, SELL,
from ibkr.contract import stock, forex
from ibkr.app import IBApp
aapl = stock("AAPL", "SMART", "USD")
eur = forex("EUR/USD")
app = IBApp("127.0.0.1", 4002, client_id=3457, account="DUE310707")
# Out:
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:cashfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfarm
# ERROR -1 2107 La conexión al centro de datos HMDS está inactiva pero debería estar disponible bajo demanda.ushmds
# ERROR -1 2158 La conexión de la granja de datos "sec-def" funciona correctamente:secdefnj
# ERROR 6 399 Mensaje de orden: COMPRAR 2,872 EUR.USD Forex Atención: El tamaño de su orden se encuentra por debajo del mínimo de EUR 20000 establecido por IdealPro y se <br>enrutará como una orden de lote fraccionario.
# openOrder id: 6 EUR CASH @ IDEALPRO : BUY MKT 2872 PreSubmitted
# orderStatus - orderid: 6 status: PreSubmitted filled: 0 remaining: 2872 lastFillPrice: 0.0
# openOrder id: 6 EUR CASH @ IDEALPRO : BUY MKT 2872 PreSubmitted
# orderStatus - orderid: 6 status: PreSubmitted filled: 0 remaining: 2872 lastFillPrice: 0.0
# Order Executed:  -1 EUR CASH USD 0000e215.67651988.01.01 6 2872 2
# ...

# %%
app.get_market_data(55,eur,)
# Out:
# 1.04445

# %%
    # market order value
app.order_value(eur, market, 1000, action=BUY)

    # market order target quantity
app.order_target_quantity(eur, market, -5)

    # market order percent
app.order_percent(eur, market, 0.1, action=BUY)
app.order_percent(eur, limit, 0.1, action=BUY, limit_price=185.0)

    # market order target value
app.order_target_value(eur, market, 3000)
app.order_target_value(eur, stop, 3000, stop_price=180.0)

    # market order target percent
app.order_target_percent(eur, market, 0.5)

time.sleep(30)
app.disconnect()
# Out:
# 1000 1.04465 1
# 24253.897 1.04445 1
# 24253.894 1.0445 1
# 3000 1.0445 1
# ERROR 2 399 Mensaje de orden: COMPRAR 957 EUR.USD Forex Atención: El tamaño de su orden se encuentra por debajo del mínimo de EUR 20000 establecido por IdealPro y se <br>enrutará como una orden de lote fraccionario.
# openOrder id: 2 EUR CASH @ IDEALPRO : BUY MKT 957 PreSubmitted
# orderStatus - orderid: 2 status: PreSubmitted filled: 0 remaining: 957 lastFillPrice: 0.0
# openOrder id: 2 EUR CASH @ IDEALPRO : BUY MKT 957 PreSubmitted
# orderStatus - orderid: 2 status: PreSubmitted filled: 0 remaining: 957 lastFillPrice: 0.0
# Order Executed:  -1 EUR CASH USD 0000e215.67651985.01.01 2 957 2
# openOrder id: 2 EUR CASH @ IDEALPRO : BUY MKT 957 Filled
# orderStatus - orderid: 2 status: Filled filled: 957 remaining: 0 lastFillPrice: 1.04455
# openOrder id: 2 EUR CASH @ IDEALPRO : BUY MKT 957 Filled
# orderStatus - orderid: 2 status: Filled filled: 957 remaining: 0 lastFillPrice: 1.04455
# ...

# %%
app.disconnect()
