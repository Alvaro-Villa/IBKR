# %%
import os

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
os.chdir(parent_dir)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/alvarovilladangos/Desktop/TradingBot/Forex

# %%
from ibkr.app import IBApp
app = IBApp("127.0.0.1", 4002, client_id=8776,
account="DUE310707")
account_values = app.get_account_values()
net_liquidation = app.get_account_values(
    "NetLiquidation")
positions = app.get_positions()
app.disconnect()
# Out:
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:cashfarm
# ERROR -1 2104 La conexión al centro de datos funciona correctamente:usfarm
# ERROR -1 2106 La conexión al centro de datos HMDS funciona correctamente:ushmds
# ERROR -1 2158 La conexión de la granja de datos "sec-def" funciona correctamente:secdefnj
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}
# {99: {'daily_pnl': 0.0, 'unrealized_pnl': 0.0, 'realized_pnl': 0.0}}

# %%
account_values
# Out:
# {'AccountCode': ('DUE310707', ''),
#  'AccountOrGroup': ('DUE310707', 'USD'),
#  'AccountReady': ('true', ''),
#  'AccountType': ('INDIVIDUAL', ''),
#  'AccruedCash': (0.0, 'USD'),
#  'AccruedCash-P': (0.0, 'EUR'),
#  'AccruedDividend': (0.0, 'EUR'),
#  'AccruedDividend-P': (0.0, 'EUR'),
#  'AvailableFunds': (244503.25, 'EUR'),
#  'AvailableFunds-P': (0.0, 'EUR'),
#  'Billable': (0.0, 'EUR'),
#  'Billable-P': (0.0, 'EUR'),
#  'BuyingPower': (1630021.68, 'EUR'),
#  'CashBalance': (231499.0, 'USD'),
#  'ColumnPrio-P': (5.0, ''),
#  'ColumnPrio-S': (1.0, ''),
#  'CorporateBondValue': (0.0, 'USD'),
#  'Cryptocurrency': (0.0, 'USD'),
#  'Currency': ('USD', 'USD'),
#  'Cushion': (1.0, ''),
#  'EquityWithLoanValue': (244503.25, 'EUR'),
#  'EquityWithLoanValue-P': (0.0, 'EUR'),
#  'ExcessLiquidity': (244503.25, 'EUR'),
#  'ExcessLiquidity-P': (0.0, 'EUR'),
#  'ExchangeRate': (0.9658476, 'USD'),
#  'FullAvailableFunds': (244503.25, 'EUR'),
#  'FullAvailableFunds-P': (0.0, 'EUR'),
#  'FullExcessLiquidity': (244503.25, 'EUR'),
#  'FullExcessLiquidity-P': (0.0, 'EUR'),
#  'FullInitMarginReq': (0.0, 'EUR'),
#  'FullInitMarginReq-P': (0.0, 'EUR'),
#  'FullMaintMarginReq': (0.0, 'EUR'),
#  'FullMaintMarginReq-P': (0.0, 'EUR'),
#  'FundValue': (0.0, 'USD'),
#  'FutureOptionValue': (0.0, 'USD'),
#  'FuturesPNL': (0.0, 'USD'),
#  'FxCashBalance': (0.0, 'USD'),
#  'GrossPositionValue': (0.0, 'EUR'),
#  'GrossPositionValue-P': (0.0, 'EUR'),
#  'Guarantee': (0.0, 'EUR'),
#  'Guarantee-P': (0.0, 'EUR'),
#  'IncentiveCoupons': (0.0, 'EUR'),
#  'IncentiveCoupons-P': (0.0, 'EUR'),
#  'IndianStockHaircut': (0.0, 'EUR'),
#  'IndianStockHaircut-P': (0.0, 'EUR'),
#  'InitMarginReq': (0.0, 'EUR'),
#  'InitMarginReq-P': (0.0, 'EUR'),
#  'IssuerOptionValue': (0.0, 'USD'),
#  'Leverage-P': (0.0, ''),
#  'Leverage-S': (0.0, ''),
#  'LookAheadAvailableFunds': (244503.25, 'EUR'),
#  'LookAheadAvailableFunds-P': (0.0, 'EUR'),
#  'LookAheadExcessLiquidity': (244503.25, 'EUR'),
#  'LookAheadExcessLiquidity-P': (0.0, 'EUR'),
#  'LookAheadInitMarginReq': (0.0, 'EUR'),
#  'LookAheadInitMarginReq-P': (0.0, 'EUR'),
#  'LookAheadMaintMarginReq': (0.0, 'EUR'),
#  'LookAheadMaintMarginReq-P': (0.0, 'EUR'),
#  'LookAheadNextChange': (0.0, ''),
#  'MaintMarginReq': (0.0, 'EUR'),
#  'MaintMarginReq-P': (0.0, 'EUR'),
#  'MoneyMarketFundValue': (0.0, 'USD'),
#  'MutualFundValue': (0.0, 'USD'),
#  'NLVAndMarginInReview': ('false', ''),
#  'NetDividend': (0.0, 'USD'),
#  'NetLiquidation': (244503.25, 'EUR'),
#  'NetLiquidation-P': (0.0, 'EUR'),
#  'NetLiquidationByCurrency': (231499.0, 'USD'),
#  'NetLiquidationUncertainty': (0.0, 'EUR'),
#  'OptionMarketValue': (0.0, 'USD'),
#  'PASharesValue': (0.0, 'EUR'),
#  'PASharesValue-P': (0.0, 'EUR'),
#  'PhysicalCertificateValue': (0.0, 'EUR'),
#  'PhysicalCertificateValue-P': (0.0, 'EUR'),
#  'PostExpirationExcess': (0.0, 'EUR'),
#  'PostExpirationExcess-P': (0.0, 'EUR'),
#  'PostExpirationMargin': (0.0, 'EUR'),
#  'PostExpirationMargin-P': (0.0, 'EUR'),
#  'RealCurrency': ('USD', 'USD'),
#  'RealizedPnL': (0.0, 'USD'),
#  'SegmentTitle-P': ('Crypto at Paxos', ''),
#  'SegmentTitle-S': ('CFD', ''),
#  'StockMarketValue': (0.0, 'USD'),
#  'TBillValue': (0.0, 'USD'),
#  'TBondValue': (0.0, 'USD'),
#  'TotalCashBalance': (231499.0, 'USD'),
#  'TotalCashValue': (244249.76, 'EUR'),
#  'TotalCashValue-P': (0.0, 'EUR'),
#  'TotalDebitCardPendingCharges': (0.0, 'EUR'),
#  'TotalDebitCardPendingCharges-P': (0.0, 'EUR'),
#  'TradingType-S': ('STKNOPT', ''),
#  'UnrealizedPnL': (0.0, 'USD'),
#  'WarrantValue': (0.0, 'USD')}
